# %%
# !pip install camelot-py
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 40 kB 25 kB/s
# ...
#      |████████████████████████████████| 204 kB 8.4 MB/s
# ...
#      |████████████████████████████████| 5.6 MB 55.1 MB/s
# ...
#      |████████████████████████████████| 4.1 MB 33.4 MB/s
# ...

# %%
# !apt install ghostscript python3-tk

# %%
# !pip install ghostscript==0.7
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import camelot
tables = camelot.read_pdf('file.pdf', f='excel', flavor='stream') #, compress=True
tables[0]
# Out:
# <Table shape=(60, 7)>

# %%
type(tables)
# Out:
# camelot.core.TableList

# %%
tables[0].parsing_report
# Out:
# {'accuracy': 96.59, 'order': 1, 'page': 1, 'whitespace': 68.1}

# %%
tables[0].to_excel('file.xlsx')

# %%
tables[0].df
# Out:
#                             0                  1                     2  \
# 0                      주문상세정보
# 1     주문번호 : 20200102-0000058
# 2   주문일자: 2020-01-02 19:37:32
# 3
# 4                    주문내역(0건)
# 5                   품목별 주문번호/
# 6                                            공급사                상품명/옵션
# 7                        배송번호
# 8
# 9                                              계
# 10
# 11                     취소(0건)
# 12              품목별 주문번호/배송번호
# 13                                           공급사                상품명/옵션
# 14                     (취소번호)
# 15
# 16                                             계
# 17
# 18                     교환(0건)
# 19              품목별 주문번호/배송번호
# 20                                           공급사                상품명/옵션
# 21                     (교환번호)
# 22
# 23
# 24                     반품(1건)
# 25              품목별 주문번호/배송번호
# 26                                           공급사                상품명/옵션
# 27                     (반품번호)
# ...

# %%
plots = camelot.plot(tables[0], kind='contour')
plots.show() # plot을 화면에 띄우기

# %%
plots = camelot.plot(tables[0], kind='grid')
plots.show() # plot을 화면에 띄우기

# %%
plots = camelot.plot(tables[0], kind='joint')
plots.show() # plot을 화면에 띄우기

# %%
plots = camelot.plot(tables[0], kind='text')
plots.show() # plot을 화면에 띄우기
